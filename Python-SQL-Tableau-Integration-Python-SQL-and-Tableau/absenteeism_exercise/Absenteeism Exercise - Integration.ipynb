# %%
from absenteeism_module import *

model = absenteeism_model('model', 'scaler')

model.load_and_clean_data('Absenteeism_new_data.csv')

model.predicted_outputs()
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# 6          1       0.0         0         0            6
# 7          0       0.0         0         1            6
# 8          0       0.0         0         1            6
# 9          1       0.0         0         0            6
# 10         0       0.0         0         1            6
# 11         0       0.0         1         0            6
# 12         0       0.0         1         0            6
# 13         0       0.0         0         1            6
# 14         0       0.0         0         0            6
# 15         0       0.0         0         0            6
# 16         0       0.0         1         0            6
# 17         1       0.0         0         0            6
# 18         0       0.0         0         1            6
# 19         1       0.0         0         0            7
# 20         0       0.0         0         1            7
# 21         0       0.0         0         1            7
# 22         1       0.0         0         0            7
# 23         1       0.0         0         0            7
# 24         0       0.0         0         1            7
# 25         0       0.0         0         1            7
# 26         0       0.0         1         0            7
# 27         1       0.0         0         0            7
# 28         0       0.0         0         1            7
# 29         1       0.0         0         0            7
# 30         0       0.0         0         1            7
# 31         0       0.0         0         1            7
# 32         0       0.0         0         1            7
# 33         0       0.0         0         1            7
# 34         1       0.0         0         0            7
# 35         1       0.0         0         0            7
# 36         1       0.0         0         0            7
# 37         0       0.0         0         0            7
# 38         0       0.0         0         0            7
# 39         0       0.0         0         0            7
#
#     Transportation Expense  Age  Body Mass Index  Education  Children  Pets  \
# 0                      179   30               19          1         0     0
# 1                      361   28               27          0         1     4
# 2                      155   34               25          0         2     0
# 3                      179   40               22          1         2     0
# 4                      155   34               25          0         2     0
# 5                      225   28               24          0         1     2
# 6                      118   46               25          0         2     0
# 7                      179   30               19          1         0     0
# 8                      118   37               28          0         0     0
# 9                      118   37               28          0         0     0
# 10                     378   36               21          0         2     4
# 11                     118   50               31          0         1     0
# 12                     233   31               21          1         1     8
# 13                     179   30               19          1         0     0
# 14                     235   48               33          0         1     5
# 15                     268   33               25          1         0     0
# 16                     118   50               31          0         1     0
# 17                     179   30               19          1         0     0
# 18                     291   40               25          0         1     1
# 19                     179   30               19          1         0     0
# 20                     118   37               28          0         0     0
# 21                     233   31               21          1         1     8
# 22                     118   37               28          0         0     0
# 23                     118   37               28          0         0     0
# 24                     233   31               21          1         1     8
# 25                     235   43               38          0         1     0
# 26                     233   31               21          1         1     8
# 27                     228   58               22          0         2     1
# 28                     118   37               28          0         0     0
# 29                     228   58               22          0         2     1
# 30                     189   33               25          0         2     2
# 31                     118   37               28          0         0     0
# 32                     361   28               27          0         1     4
# 33                     225   28               24          0         1     2
# 34                     369   31               25          0         3     0
# 35                     289   33               30          0         2     1
# 36                     235   37               29          1         1     1
# 37                     118   40               34          0         1     8
# 38                     231   39               35          0         2     2
# 39                     179   53               25          0         1     1
#
#     Probability  Prediction
# 0      0.462915           0
# 1      0.692057           1
# 2      0.258066           0
# 3      0.411592           0
# 4      0.712007           1
# 5      0.737730           1
# 6      0.821531           1
# 7      0.462915           0
# 8      0.382517           0
# 9      0.814923           1
# 10     0.310808           0
# 11     0.877630           1
# 12     0.941359           1
# 13     0.462915           0
# 14     0.278840           0
# 15     0.200815           0
# 16     0.877630           1
# 17     0.859674           1
# 18     0.319652           0
# 19     0.879256           1
# 20     0.424076           0
# 21     0.661984           1
# 22     0.839584           1
# 23     0.839584           1
# 24     0.661984           1
# 25     0.252104           0
# 26     0.950202           1
# 27     0.902845           1
# 28     0.424076           0
# 29     0.902845           1
# 30     0.322674           0
# 31     0.424076           0
# 32     0.273164           0
# 33     0.319911           0
# 34     0.536944           1
# 35     0.640912           1
# 36     0.823569           1
# 37     0.384864           0
# 38     0.127862           0
# 39     0.362675           0

# %%
import psycopg2

# %%
conn = psycopg2.connect("dbname=predicted_outputs user=paulo password =paulo")

# %%
cursor = conn.cursor()

# %%
cursor.execute("DROP TABLE predicted_outputs;")

cursor.execute("""CREATE TABLE predicted_outputs(
  reason_1 BOOLEAN NOT NULL,
  reason_2 BOOLEAN NOT NULL,
  reason_3 BOOLEAN NOT NULL,
  reason_4 BOOLEAN NOT NULL,
  month_value INT NOT NULL,
  transportation_expense INT NOT NULL,
  age INT NOT NULL,
  body_mass_index INT NOT NULL,
  education BOOLEAN NOT NULL,
  children INT NOT NULL,
  pets INT NOT NULL, 
  probability FLOAT NOT NULL,
  prediction BIT NOT NULL
);""")
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# <ipython-input-12-f85816144e23> in <module>
# ----> 1 cursor.execute("DROP TABLE predicted_outputs;")
#       2 cursor.execute("""CREATE TABLE predicted_outputs(
#       3   reason_1 BOOLEAN NOT NULL,
#       4   reason_2 BOOLEAN NOT NULL,
#       5   reason_3 BOOLEAN NOT NULL,
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block
